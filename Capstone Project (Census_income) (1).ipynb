# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\SHREE\Downloads\census-income.csv")

# %%
data.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country annual_income
# 0          2174             0              40  United-States         <=50K
# ...

# %%
data.shape
# Out:
# (32561, 15)

# %% [markdown]
# #EDA (Exploratory data analysis)

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  annual_income   32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB
# None

# %%
print(data.describe())
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
print(data.isnull().sum())
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# annual_income     0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.shape
# Out:
# (32561, 15)

# %%
#drop duplicate values
data.drop_duplicates(keep = 'first',inplace =True)

# %%
data.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country annual_income
# 0          2174             0              40  United-States         <=50K
# ...

# %%
data.shape
# Out:
# (32537, 15)

# %%
#Data manipulation question

#Q1 Extracting the “education” column and store it in “census_ed”
census_ed = data['education'].copy()
census_ed
# Out:
# 0         Bachelors
# 1         Bachelors
# 2           HS-grad
# 3              11th
# 4         Bachelors
#             ...
# 32556    Assoc-acdm
# 32557       HS-grad
# 32558       HS-grad
# 32559       HS-grad
# 32560       HS-grad
# Name: education, Length: 32537, dtype: object

# %%
#Extracting all the columns from “age” to “relationship” and store it in “census_seq”.
census_seq = data.loc[:,'age':'relationship'].copy()
census_seq
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship
# 0           Never-married       Adm-clerical  Not-in-family
# 1      Married-civ-spouse    Exec-managerial        Husband
# ...

# %%
#Q3 Extract the column number “0”, “5”, “6” and store it in “census_col”.
census_col = data.iloc[:,[0,5,6]].copy()
census_col
# Out:
#        age      marital-status         occupation
# 0       39       Never-married       Adm-clerical
# 1       50  Married-civ-spouse    Exec-managerial
# 2       38            Divorced  Handlers-cleaners
# 3       53  Married-civ-spouse  Handlers-cleaners
# 4       28  Married-civ-spouse     Prof-specialty
# ...    ...                 ...                ...
# 32556   27  Married-civ-spouse       Tech-support
# 32557   40  Married-civ-spouse  Machine-op-inspct
# 32558   58             Widowed       Adm-clerical
# 32559   22       Never-married       Adm-clerical
# 32560   52  Married-civ-spouse    Exec-managerial
#
# [32537 rows x 3 columns]

# %%
#Q4. Extracting all the male employees who work in state-gov and store it in “male_gov”.
male_gov = data[(data["sex"] == "Male") & (data["workclass"] == 'State-gov')]
male_gov
# Out:
#        age  workclass  fnlwgt     education  education-num  \
# 0       39  State-gov   77516     Bachelors             13
# 11      30  State-gov  141297     Bachelors             13
# 34      22  State-gov  311512  Some-college             10
# 48      41  State-gov  101603     Assoc-voc             11
# 123     29  State-gov  267989     Bachelors             13
# ...    ...        ...     ...           ...            ...
# 32163   36  State-gov  135874     Bachelors             13
# 32241   45  State-gov  231013     Bachelors             13
# 32321   54  State-gov  138852       HS-grad              9
# 32324   42  State-gov  138162  Some-college             10
# 32360   58  State-gov  200316       HS-grad              9
#
#            marital-status       occupation   relationship                race  \
# 0           Never-married     Adm-clerical  Not-in-family               White
# 11     Married-civ-spouse   Prof-specialty        Husband  Asian-Pac-Islander
# ...

# %%
#Q5. Extracting all Female employees who work in Private
Fe_private = data[(data["sex"] == "Female") & (data["workclass"] == 'Private')]
Fe_private
# Out:
#        age workclass  fnlwgt   education  education-num  \
# 4       28   Private  338409   Bachelors             13
# 5       37   Private  284582     Masters             14
# 6       49   Private  160187         9th              5
# 8       31   Private   45781     Masters             14
# 12      23   Private  122272   Bachelors             13
# ...    ...       ...     ...         ...            ...
# 32538   38   Private  139180   Bachelors             13
# 32544   31   Private  199655     Masters             14
# 32546   37   Private  198216  Assoc-acdm             12
# 32556   27   Private  257302  Assoc-acdm             12
# 32558   58   Private  151910     HS-grad              9
#
#               marital-status       occupation   relationship   race     sex  \
# 4         Married-civ-spouse   Prof-specialty           Wife  Black  Female
# 5         Married-civ-spouse  Exec-managerial           Wife  White  Female
# ...

# %%
#Q6. Extract all the 39 year olds who either have a bachelor's degree or who are native of the United States
#and store the result in “census_us”.
census_us =  data[(data["age"] == 39) | (data["education"] == 'Bachelors') |(data["native-country"] == 'United-States')]
census_us
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
 # Q7.Getting the count of different levels of the “workclass” column. 
workclass_counts = data['workclass'].value_counts()
print(workclass_counts)
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
#Q8 Here we are calculating the mean of capital gain on the bases of work class
mean_cap_wc = data.groupby('workclass')['capital-gain'].mean()
print(mean_cap_wc)
# Out:
# workclass
# ?                    606.795752
# Federal-gov          833.232292
# Local-gov            880.202580
# Never-worked           0.000000
# Private              890.119834
# Self-emp-inc        4875.693548
# Self-emp-not-inc    1886.804331
# State-gov            701.699538
# Without-pay          487.857143
# Name: capital-gain, dtype: float64

# %%
#Q9 Create a separate dataframe with the details of males and females from the census data that has income more than 50,000
#For male 
male_data = data[(data['annual_income']=='>50K') & (data['sex'] == 'Male')].copy()
male_data
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 14      40           Private  121772     Assoc-voc             11
# ...    ...               ...     ...           ...            ...
# 32532   34           Private  204461     Doctorate             16
# 32533   54           Private  337992     Bachelors             13
# 32539   71                 ?  287372     Doctorate             16
# 32554   53           Private  321865       Masters             14
# 32557   40           Private  154374       HS-grad              9
#
#            marital-status         occupation relationship                race  \
# 7      Married-civ-spouse    Exec-managerial      Husband               White
# ...

# %%
Female_data = data[(data['annual_income'] =='>50K') & (data['sex'] == 'Female')].copy()
Female_data
# Out:
#        age         workclass  fnlwgt    education  education-num  \
# 8       31           Private   45781      Masters             14
# 19      43  Self-emp-not-inc  292175      Masters             14
# 52      47           Private   51835  Prof-school             15
# 67      53           Private  169846      HS-grad              9
# 84      44           Private  343591      HS-grad              9
# ...    ...               ...     ...          ...            ...
# 32530   35                 ?  320084    Bachelors             13
# 32536   34           Private  160216    Bachelors             13
# 32538   38           Private  139180    Bachelors             13
# 32545   39         Local-gov  111499   Assoc-acdm             12
# 32560   52      Self-emp-inc  287927      HS-grad              9
#
#            marital-status       occupation   relationship   race     sex  \
# 8           Never-married   Prof-specialty  Not-in-family  White  Female
# ...

# %%
#Q10 Checking % of people from US who earn <=50,000 anually and work under private.
p_le50k = data[(data['native-country'] == 'United-States') & (data['annual_income'] == '<=50K')&(data['workclass'] == 'Private')]
total = len(data)
percentage = (len(p_le50k)/total)*100
percentage
# Out:
# 47.88394750591634

# %%
# Q11 Calculating the percentage of married people in the census data.
data['marital-status'].value_counts()
# Out:
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital-status, dtype: int64

# %%
total=len(data['marital-status'])
married=14970+418+23
precen_mar=(married/total)*100
precen_mar
# Out:
# 47.36453883271353

# %%
#Q12 Calculatig the percentage of high school graduates earning more than 50,000 annually
data['education'].value_counts()
# Out:
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64

# %%
HSG_m50k=len(data[(data['education']=='HS-grad') &(data['annual_income']=='>50K')])

percentage_hsg_m50k=(HSG_m50k/total)*100

percentage_hsg_m50k
# Out:
# 5.144911946399484

# %% [markdown]
# # Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
Model = LinearRegression() # making an object of linear regression class

# %%
X=data[['education-num']] #Independent variable
y=data['hours-per-week']  #Dependent Variable

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=.30,random_state=1)
Model.fit(X_train,y_train)
y_pred = Model.predict(X_test)

# %%
y_pred
# Out:
# array([42.46889744, 42.46889744, 39.59426798, ..., 39.59426798,
#        42.46889744, 43.1875548 ])

# %%
y_test
# Out:
# 12580    34
# 11850    40
# 9402     40
# 32153    10
# 19725    60
#          ..
# 20768    60
# 1321     30
# 3529     40
# 20795    40
# 7671     40
# Name: hours-per-week, Length: 9762, dtype: int64

# %%
error=y_test-y_pred
error
# Out:
# 12580    -8.468897
# 11850    -2.468897
# 9402      0.405732
# 32153   -25.282324
# 19725    17.531103
#            ...
# 20768    17.531103
# 1321    -10.312925
# 3529      0.405732
# 20795    -2.468897
# 7671     -3.187555
# Name: hours-per-week, Length: 9762, dtype: float64

# %%
print('mean_squared_error :',mean_squared_error(y_test,y_pred))

print('root-mean-square error :',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# mean_squared_error : 149.27671677600688
# root-mean-square error : 12.217885118792323

# %% [markdown]
# # Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
lo=LogisticRegression()

# %%
X=data['occupation'] #Independent Variable
X=pd.DataFrame(X)

# %%
X[['occupation']].value_counts()
# Out:
# occupation
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# dtype: int64

# %%
data['annual_income'].value_counts() #Dependent variable
# Out:
# <=50K    24698
# >50K      7839
# Name: annual_income, dtype: int64

# %%
y=data['annual_income'].replace('<=50K',0).replace('>50K',1)
y.value_counts()
# Out:
# 0    24698
# 1     7839
# Name: annual_income, dtype: int64

# %%
# giving particular labels to the elements in my columns
L=LabelEncoder()

# %%
X=L.fit_transform(x)

# %%
X =pd.DataFrame(X)

# %%
X.head()
# Out:
#     0
# 0  12
# 1  12
# 2   8
# 3   6
# 4  12

# %%
X.to_string() #To check labels of whole columns
# Out:
# '        0\n0      12\n1      12\n2       8\n3       6\n4      12\n5      13\n6       4\n7       8\n8      13\n9      12\n10      9\n11     12\n12     12\n13     11\n14     10\n15      3\n16      8\n17      8\n18      6\n19     13\n20     15\n21      8\n22      4\n23      6\n24      8\n25     12\n26      8\n27      9\n28      8\n29      8\n30     11\n31      9\n32     12\n33      9\n34      9\n35      6\n36      9\n37      8\n38      9\n39     11\n40      4\n41     12\n42     12\n43      8\n44      8\n45     12\n46      8\n47     13\n48     10\n49     10\n50      9\n51      8\n52     14\n53     12\n54      8\n55      9\n56      2\n57     10\n58      8\n59      8\n60     12\n61      3\n62      8\n63     15\n64      9\n65      8\n66      9\n67      8\n68      9\n69      9\n70      9\n71     12\n72     12\n73      9\n74      9\n75      8\n76     11\n77      5\n78      6\n79      3\n80      8\n81     12\n82      8\n83      8\n84      8\n85      8\n86      8\n87     13\n88      4\n89     
# ...

# %%
X.value_counts()
# Out:
# 8     10494
# 9      7282
# 12     5353
# 13     1722
# 10     1382
# 6      1175
# 11     1067
# 5       933
# 3       645
# 14      576
# 4       514
# 7       433
# 15      413
# 2       332
# 1       166
# 0        50
# dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.35,random_state=1)
lo=LogisticRegression()
lo.fit(X_train,y_train)
y_pred=lo.predict(X_test)

print('confusion_matrix :')
print(confusion_matrix(y_pred,y_test))
print('accuracy_score :',accuracy_score(y_test,y_pred))
# Out:
# confusion_matrix :
# [[8357 2093]
#  [ 372  566]]
# accuracy_score : 0.783544081489287

# %%
data.head(1)
# Out:
#    age  workclass  fnlwgt  education  education-num marital-status  \
# 0   39  State-gov   77516  Bachelors             13  Never-married
#
#      occupation   relationship   race   sex  capital-gain  capital-loss  \
# 0  Adm-clerical  Not-in-family  White  Male          2174             0
#
#    hours-per-week native-country annual_income
# 0              40  United-States         <=50K

# %%
d=data[['age','workclass','education']]    #We are taking this because income is most related to these columns
d.head()
# Out:
#    age         workclass  education
# 0   39         State-gov  Bachelors
# 1   50  Self-emp-not-inc  Bachelors
# 2   38           Private    HS-grad
# 3   53           Private       11th
# 4   28           Private  Bachelors

# %%
d['workclass'].value_counts()
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
x=d.apply(L.fit_transform)
x.head()
# Out:
#    age  workclass  education
# 0   22          7          9
# 1   33          6          9
# 2   21          4         11
# 3   36          4          1
# 4   11          4          9

# %%
y=data['annual_income'].replace('<=50K',0).replace('>50K',1)

# %%
y.value_counts()
# Out:
# 0    24698
# 1     7839
# Name: annual_income, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=42)
lo=LogisticRegression()
lo.fit(x_train,y_train)
y_pred=lo.predict(x_test)

print('confusion_matrix :')
print(confusion_matrix(y_pred,y_test))
print('accuracy_score :',accuracy_score(y_test,y_pred))
# Out:
# confusion_matrix :
# [[4791 1558]
#  [ 114   45]]
# accuracy_score : 0.7430854333128457

# %% [markdown]
# # Decision Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier
data.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country annual_income
# 0          2174             0              40  United-States         <=50K
# ...

# %%
data.education= data.education.replace(['Preschool', '1st-4th', '5th-6th', '7th-8th', '9th','10th', '11th', '12th'], 'School')
data.education = data.education.replace(['Assoc-voc', 'Assoc-acdm', 'Prof-school', 'Some-college'], 'Higher')
data['marital-status']= data['marital-status'].replace(['Married-civ-spouse', 'Married-AF-spouse'], 'married')
data['marital-status']= data['marital-status'].replace(['Never-married'], 'not-married')
data['marital-status']= data['marital-status'].replace(['Divorced', 'Separated','Widowed','Married-spouse-absent'], 'other')
data.annual_income = data.annual_income.replace('<=50K', 0)
data.annual_income = data.annual_income.replace('>50K', 1)
data.head()
# Out:
#    age         workclass  fnlwgt  education  education-num marital-status  \
# 0   39         State-gov   77516  Bachelors             13    not-married
# 1   50  Self-emp-not-inc   83311  Bachelors             13        married
# 2   38           Private  215646    HS-grad              9          other
# 3   53           Private  234721     School              7        married
# 4   28           Private  338409  Bachelors             13        married
#
#           occupation   relationship   race     sex  capital-gain  \
# 0       Adm-clerical  Not-in-family  White    Male          2174
# 1    Exec-managerial        Husband  White    Male             0
# 2  Handlers-cleaners  Not-in-family  White    Male             0
# 3  Handlers-cleaners        Husband  Black    Male             0
# 4     Prof-specialty           Wife  Black  Female             0
#
#    capital-loss  hours-per-week native-country  annual_income
# 0             0              40  United-States              0
# ...

# %%
data=data.apply(L.fit_transform)
data.head()
# Out:
#    age  workclass  fnlwgt  education  education-num  marital-status  \
# 0   22          7    2671          0             12               1
# 1   33          6    2926          0             12               0
# 2   21          4   14086          2              8               2
# 3   36          4   15336          5              6               0
# 4   11          4   19355          0             12               0
#
#    occupation  relationship  race  sex  capital-gain  capital-loss  \
# 0           1             1     4    1            25             0
# 1           4             0     4    1             0             0
# 2           6             1     4    1             0             0
# 3           6             0     2    1             0             0
# 4          10             5     2    0             0             0
#
#    hours-per-week  native-country  annual_income
# 0              39              39              0
# 1              12              39              0
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=42)
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
y_pred=dt.predict(x_test)

print('confusion_matrix :')
print(confusion_matrix(y_pred,y_test))
print('accuracy_score :',accuracy_score(y_test,y_pred))
# Out:
# confusion_matrix :
# [[5695 1314]
#  [ 464  662]]
# accuracy_score : 0.781438229870928

# %% [markdown]
# # Random Forest Model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=42)
rf=RandomForestClassifier(n_estimators=300)
rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)

print('confusion_matrix :')
print(confusion_matrix(y_pred,y_test))
print('accuracy_score :',accuracy_score(y_test,y_pred))
# Out:
# confusion_matrix :
# [[5668 1284]
#  [ 491  692]]
# accuracy_score : 0.7818070067609096

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.92      0.86      6159
#            1       0.58      0.35      0.44      1976
#
#     accuracy                           0.78      8135
#    macro avg       0.70      0.64      0.65      8135
# weighted avg       0.76      0.78      0.76      8135
